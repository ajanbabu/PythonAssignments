# %%
#Print 'Correct' if i===10

# %%
i =int(input('Enter the value:'))

# %%
if(i== 10):
    print("Correct")
# Out:
# Correct

# %%
# Check the password, using if and else

# %%
password =input('Enter the password:')
# Out:
# Enter the password: skcnjscn

# %%
if(password == 'HOPE@123'):
    print("Your password is correct")
else:
    print("Your password is Incorrect")
# Out:
# Your password is Incorrect

# %%
#Catagory the people bt their age like children, adult, Citizen, Senior citizen....

# %%
age =int(input('Enter the value:'))
# Out:
# Enter the value: 18

# %%
if (age < 13):
    print("Children")
elif(age < 20):
    print("adult")
elif(age < 60):
    print("Citizen")
else:
    print("Senior Children")
# Out:
# adult

# %%
#Find whether given number is positive or negative

# %%
number = int(input("Enter any number:"))
# Out:
# Enter any number: -4

# %%
if(number > 1):
    print("no is positive")
else:
    print("no is negative")
# Out:
# no is negative

# %%
#check whether given number is divisible by 5

# %%
number = int(input("Enter a number to checck:"))

# %%
if(number % 5 == 0):
    print("Divisib
