# %%
print("Hope AI")
# Out:
# Hope AI

# %%
hopeAI = input("Enter Your Institute name?:")
# Out:
# Enter Your Institute name?: Welcome

# %%
print(hopeAI)
# Out:
# Welcome

# %%
name = input("Enter Your name?:")
age = int(input("Enter Your age?:"))
schoolName = input("Enter Your School name?:")
degree = input("Enter Your degree?:")
# Out:
# Enter Your name?: Ajan
# Enter Your age?: 35
# Enter Your School name?: st marys
# Enter Your degree?: b.E

# %%
print(name)
print(age)
print(schoolName)
print(degree)
# Out:
# Ajan
# 35
# st marys
# b.E

# %%
# Addition

# %%
a = 43
b = 34
add = a + b

# %%
print(add)
# Out:
# 77

# %%
# Subtraction

# %%
a = 43
b = 34
sub = a - b

# %%
print(sub)
# Out:
# 9

# %%
# Multiplication

# %%
a = 43
b = 34
mul = a * b

# %%
print(mul)
# Out:
# 1462

# %%
# Division

# %%
a = 76
b = 31
div = a / b

# %%
print(div)
# Out:
# 2.4516129032258065

# %%
#Floor Division

# %%
a = 76
b = 31
div = a / b

# %%
floorDiv = round(div)
print(floorDiv)
# Out:
# 2

# %%
#Modulo

# %%
a = 76
b = 31
mod = a % b
print(mod)
# Out:
# 14

# %%
#power

# %%
a = 4
b = 4
pow = a ** b
print(pow)
# Out:
# 256
